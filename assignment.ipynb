# %%
# !python -m pip install yfinance
# !python -m pip install duckduckgo_search
# !python -m pip install ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 25.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [ddgs]4/6 [h2]
# ...

# %%
from sentiment import *
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
run_sentiment_pipeline("Aplhabet")
# Out:
# {'company_name': 'Alphabet',
#  'stock_code': 'GOOGL',
#  'newsdesc': "Meta Platforms is considering using Google's AI models to enhance its advertising business, leading to a 1.5% rise in Alphabet's stock in afterhours trading.",
#  'sentiment': 'Positive',
#  'people_names': [],
#  'places_names': [],
#  'other_companies_referred': ['Meta Platforms'],
#  'related_industries': ['Technology',
#   'Advertising',
#   'Artificial Intelligence'],
#  'market_implications': "The collaboration could enhance Alphabet's position in the AI and advertising sectors, potentially leading to increased revenue and stock performance.",
#  'confidence_score': 0.85}

# %%
mlflow.end_run()

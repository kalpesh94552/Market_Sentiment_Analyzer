# %%
temp = {  "company_name": "",  "stock_code": "",  "newsdesc": "",  "sentiment": "Positive/Negative/Neutral",  "people_names": [],  "places_names": [],  "other_companies_referred": [],  "related_industries": [],  "market_implications": "",  "confidence_score": 0.0 }

# %%
# !python -m pip install yfinance
# !python -m pip install duckduckgo_search

# %%
from Market_Sentiment_Analyzer.sentiment import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sentiment import *
#
# File ~/Desktop/GenAiCourse/code/GAAI-B4-Azure/sentiment.py:7
#       5 from typing import List
#       6 from pydantic import BaseModel, Field
# ----> 7 from langchain_openai import AzureChatOpenAI
#       8 from langchain.prompts import ChatPromptTemplate, PromptTemplate
#       9 from langchain_core.output_parsers import JsonOutputParser
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Run sentiment pipeline for a company")
    parser.add_argument("--company", type=str, required=True, help="Company name (e.g., 'Microsoft')")
    args = parser.parse_args()
    
    result = run_sentiment_pipeline(args.company)
    print(json.dumps(result, indent=2))
# Out:
# usage: ipykernel_launcher.py [-h] --company COMPANY
# ipykernel_launcher.py: error: the following arguments are required: --company
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/zadmin/Desktop/GAAI-B4-Azure/genai/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
result = run_sentiment_pipeline("Microsoft")
# Out:
# /home/zadmin/Desktop/GAAI-B4-Azure/genai/lib/python3.12/site-packages/langchain_community/utilities/duckduckgo_search.py:63: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = run_sentiment_pipeline("Microsoft")
#
# File ~/Desktop/GAAI-B4-Azure/sentiment.py:98, in run_sentiment_pipeline(company_name)
#      96 with mlflow.start_run(nested=True, run_name="ticker_extraction"):
#      97     mlflow.log_param("step", "ticker_extraction")
# ---> 98     ticker = get_stock_ticker(company_name, llm, search_tool)
#      99     mlflow.log_param("extracted_ticker", ticker)
#     100     mlflow.log_metric("ticker_confidence", 1.0)  # Assume high for now
#
# ...

# %%
print(json.dumps(result, indent=2))
